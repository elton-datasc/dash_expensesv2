# %%
import pandas as pd
import os

# %%
os.path.isdir("../src/data/")
# Out:
# True

# %%
os.path.exists("../src/data/transacoes.csv")
# Out:
# True

# %%
os.listdir("..\\src\\data/")
# Out:
# ['expenses.CSV',
#  'expenses.di.json',
#  'expenses.json',
#  'pt-BR.json',
#  'transacoes.csv']

# %%
os.path.abspath("../src/data/")
# Out:
# 'C:\\Users\\dienert\\OneDrive\\Aulas\\CapturaEVisualizacao\\codigos\\expensesv2\\src\\data'

# %%
df = pd.read_csv("../src/data/transacoes.csv", sep=';')

# %%
df.sort_values(['Trans Date'])
# Out:
#     Trans Date                               Description Parcelado Parcela  \
# 38  06/06/2018                              BFP CALCADOS      PARC   04/04
# 39  08/21/2018                               AllianzGASV      PARC   02/06
# 18  09/02/2018          Uber Do Brasil TecnologSAO PAULO       NaN     NaN
# 17  09/02/2018          Uber Do Brasil TecnologSAO PAULO       NaN     NaN
# 21  09/07/2018          Uber Do Brasil TecnologSAO PAULO       NaN     NaN
# 20  09/07/2018          Uber Do Brasil TecnologSAO PAULO       NaN     NaN
# 11  09/07/2018                       RECVIVO*83981821478       NaN     NaN
# 19  09/07/2018          Uber Do Brasil TecnologSAO PAULO       NaN     NaN
# 2   09/10/2018  PGTO DEBITO CONTA 1617 000005071  200211       NaN     NaN
# 23  09/11/2018          Uber Do Brasil TecnologSAO PAULO       NaN     NaN
# 22  09/11/2018          Uber Do Brasil TecnologSAO PAULO       NaN     NaN
# ...
