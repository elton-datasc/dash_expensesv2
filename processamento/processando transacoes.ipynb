# %%
import pandas as pd

# %%
df = pd.read_csv('transacoes.csv', sep=';')

# %%
df
# Out:
#       Trans Date                            Description Parcelado Parcela  \
# 0     10/13/2015  PGTO DEBITO CONTA 1617 000005047  200       NaN     NaN
# 1     10/15/2015  AJUSTE A CREDITO VAR.CAMBIAL COMPRA E       NaN     NaN
# 2     09/25/2015     AUTO POSTO DE COMBUSTI JOAO PESSOA       NaN     NaN
# 3     10/16/2015                        CENTAURO CE 227       NaN     NaN
# 4     10/17/2015                  MICROSOFT XBOX OFFICE       NaN     NaN
# 5     10/19/2015                  MONDIAL SEGURO VIAGEM       NaN     NaN
# 6     10/19/2015                               AMERICAN       NaN     NaN
# 7     08/26/2015                          PAYPAL DO BRA      PARC   02/10
# 8     07/26/2015                          CENTAURO - CE      PARC   03/06
# 9     01/27/2015                          MERCADOPAGO*M      PARC   09/12
# 10    06/05/2015                                 IPLACE      PARC   05/10
# 11    07/14/2015                               JURANDIR      PARC   04/06
# ...
